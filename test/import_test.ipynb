# %%
import os, sys
# add parent directory to system path to use local code instead of installed library
parent_dir = os.path.dirname(os.path.abspath(''))
sys.path.insert(0, parent_dir)

from music_model.conversion import *

# %%
score = import_xml("resources/repeats.musicxml")
show(score)
#write_xml_file(score, "output.musicxml")

# %%
score.unfold()
# Out:
# 0 - 1
# 0 - 4
# 2 - 4
# 1 - 6
# 5 - 7
# 0 - 7

# %%
import heapq

array1 = [1, 3, 8]
array2 = [2, 4, 9]
gen = heapq.merge(array1, array2)
print(next(gen))
array1[1] = 5
print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
